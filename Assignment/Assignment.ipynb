# %%
# import numpy as np
import pandas as pd

# %%
df = pd.read_csv("machine-readable-business-employment-data-june-2022-quarter.csv")

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df.count()
# Out:
# Series_reference    20254
# Period              20254
# Data_value          15795
# Suppressed           2875
# STATUS              20254
# UNITS               20254
# Magnitude           20254
# Subject             20254
# Group               20254
# Series_title_1      20254
# Series_title_2      20254
# Series_title_3      20254
# Series_title_4          0
# Series_title_5          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           4459
# Suppressed          17379
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4      20254
# Series_title_5      20254
# dtype: int64

# %%
df1=df.fillna({
    'Series_reference':'-1',
    'Data_value':df['Data_value'].min(),
    'Suppressed':'10002',
    'Series_title_4':'10003',
    'Series_title_5':'10004',
})

# %%
df1.isnull().sum()
# Out:
# Series_reference    0
# Period              0
# Data_value          0
# Suppressed          0
# STATUS              0
# UNITS               0
# Magnitude           0
# Subject             0
# Group               0
# Series_title_1      0
# Series_title_2      0
# Series_title_3      0
# Series_title_4      0
# Series_title_5      0
# dtype: int64

# %%
df1
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0      10002      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0      10002      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0      10002      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0      10002      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0      10002      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06   2196974.0          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09   2196974.0          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12   2196974.0          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03   2196974.0          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06   2196974.0          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df1['Data_value'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20249     True
# 20250     True
# 20251     True
# 20252     True
# 20253     True
# Name: Data_value, Length: 20254, dtype: bool

# %%
for i in df1.head():
    print(df1[i].duplicated().sum())
# Out:
# 19792
# 20209
# 6111
# 20252
# 20251
# 20252
# 20252
# 20253
# 20249
# 20251
# 20138
# 20251
# 20253
# 20253

# %%
df1.iloc[0:300:30 , 0::3]
# Out:
#     Series_reference Suppressed  Magnitude Series_title_1 Series_title_4
# 0        BDCQ.SEA1AA      10002          0    Filled jobs          10003
# 30       BDCQ.SEA1AA      10002          0    Filled jobs          10003
# 60       BDCQ.SEA1AS      10002          0    Filled jobs          10003
# 90       BDCQ.SEA1AT      10002          0    Filled jobs          10003
# 120      BDCQ.SEA1AT      10002          0    Filled jobs          10003
# 150      BDCQ.SEA1BA      10002          0    Filled jobs          10003
# 180      BDCQ.SEA1BS      10002          0    Filled jobs          10003
# 210      BDCQ.SEA1BS      10002          0    Filled jobs          10003
# 240      BDCQ.SEA1BT      10002          0    Filled jobs          10003
# 270      BDCQ.SEA1CA      10002          0    Filled jobs          10003

# %%
df1.count()
# Out:
# Series_reference    20254
# Period              20254
# Data_value          20254
# Suppressed          20254
# STATUS              20254
# UNITS               20254
# Magnitude           20254
# Subject             20254
# Group               20254
# Series_title_1      20254
# Series_title_2      20254
# Series_title_3      20254
# Series_title_4      20254
# Series_title_5      20254
# dtype: int64

# %%
print(df1['Data_value'].mean())
df1['Data_value'].describe()
# Out:
# 531694.7604786464
# count    2.025400e+04
# mean     5.316948e+05
# std      8.999461e+05
# min      1.225683e+00
# 25%      2.679645e+03
# 50%      2.136000e+04
# 75%      2.386078e+05
# max      2.196974e+06
# Name: Data_value, dtype: float64

# %%
df1.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 20249    BDCQ.SEE3999A  2017.06   2196974.0          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09   2196974.0          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12   2196974.0          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03   2196974.0          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06   2196974.0          Y      C  Number
#
#        Magnitude                         Subject  \
# 20249          0  Business Data Collection - BDC
# 20250          0  Business Data Collection - BDC
# 20251          0  Business Data Collection - BDC
# 20252          0  Business Data Collection - BDC
# 20253          0  Business Data Collection - BDC
#
#                                               Group  \
# 20249  Territorial authority by employment variable
# 20250  Territorial authority by employment variable
# 20251  Territorial authority by employment variable
# ...

# %%
Maximum=df1.max()
Maximum
# Out:
# Series_reference                                   BDCQ.SEE3999A
# Period                                                   2022.06
# Data_value                                             2196974.0
# Suppressed                                                     Y
# STATUS                                                         R
# UNITS                                                      Value
# Magnitude                                                      6
# Subject                           Business Data Collection - BDC
# Group               Territorial authority by employment variable
# Series_title_1                                    Total earnings
# Series_title_2                                   Wholesale Trade
# Series_title_3                                             Trend
# Series_title_4                                             10003
# Series_title_5                                             10004
# dtype: object

# %%
Minimum=df1.min()
Minimum
# Out:
# Series_reference                       BDCQ.SEA1AA
# Period                                     2011.06
# Data_value                                1.225683
# Suppressed                                   10002
# STATUS                                           C
# UNITS                                       Number
# Magnitude                                        0
# Subject             Business Data Collection - BDC
# Group                   Age by employment variable
# Series_title_1                         Filled jobs
# Series_title_2                               15-19
# Series_title_3                              Actual
# Series_title_4                               10003
# Series_title_5                               10004
# dtype: object

# %%
total=0
for i in df1['Data_value'].index:
    if df1['Data_value'][i]==Minimum['Data_value']:
        total+=1
#         print("Minimum indexes: "+str(i))
print("Total minimum",total)
# Out:
# Total minimum 4460

# %%
df1.corr()
# Out:
#               Period  Data_value  Magnitude
# Period      1.000000    0.032075  -0.039785
# Data_value  0.032075    1.000000  -0.229514
# Magnitude  -0.039785   -0.229514   1.000000
