# %%
# import numpy as np
import pandas as pd

# %%
df = pd.read_csv("machine-readable-business-employment-data-june-2022-quarter.csv")

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           4459
# Suppressed          17379
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4      20254
# Series_title_5      20254
# dtype: int64

# %%
df1=df.fillna({
    'Series_reference':'-1',
    'Data_value':10001,
    'Suppressed':'10002',
    'Series_title_4':'10003',
    'Series_title_5':'10004',
})

# %%
df1.isnull().sum()
# Out:
# Series_reference    0
# Period              0
# Data_value          0
# Suppressed          0
# STATUS              0
# UNITS               0
# Magnitude           0
# Subject             0
# Group               0
# Series_title_1      0
# Series_title_2      0
# Series_title_3      0
# Series_title_4      0
# Series_title_5      0
# dtype: int64

# %%
df1
# Out:
#       Series_reference   Period Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06    80078.0      10002      F  Number
# 1          BDCQ.SEA1AA  2011.09    78324.0      10002      F  Number
# 2          BDCQ.SEA1AA  2011.12    85850.0      10002      F  Number
# 3          BDCQ.SEA1AA  2012.03    90743.0      10002      F  Number
# 4          BDCQ.SEA1AA  2012.06    81780.0      10002      F  Number
# ...                ...      ...        ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06      10001          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09      10001          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12      10001          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03      10001          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06      10001          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20249    False
# 20250    False
# 20251    False
# 20252    False
# 20253    False
# Length: 20254, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# 0
